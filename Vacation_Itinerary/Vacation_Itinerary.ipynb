# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../WeatherPy_vacation.csv")
vacation_df.head(60)
# Out:
#     City_ID                  City Country  Max Temp   Current Description  \
# 0         1             Fairbanks      US     74.61       overcast clouds
# 1         5               Rikitea      PF     74.03         moderate rain
# 2         6               Salalah      OM     77.59            light rain
# 3        13              Mabaruma      GY     74.75       overcast clouds
# 4        16                Atuona      PF     77.88            few clouds
# 5        17               Camocim      BR     77.79       overcast clouds
# 6        20               Nioaque      BR     75.00             clear sky
# 7        30          Puerto Ayora      EC     71.55       overcast clouds
# 8        31             Catamarca      AR     75.09             clear sky
# 9        32                 Vaini      TO     78.96      scattered clouds
# 10       34             Jamestown      US     70.52             clear sky
# 11       38                Harper      LR     75.96         broken clouds
# 12       42        Villa De Reyes      MX     79.63      scattered clouds
# 13       45          Ponta Do Sol      PT     75.13             clear sky
# 14       49           East London      ZA     71.22             clear sky
# 15       52                 Praya      CV     75.74            few clouds
# 16       57                  Puri      IN     79.32       overcast clouds
# 17       62       Arraial Do Cabo      BR     71.24            few clouds
# 18       63               Baracoa      CU     79.83       overcast clouds
# 19       68               Lom Sak      TH     75.09       overcast clouds
# 20       70                  Tual      ID     79.41      scattered clouds
# 21       72                Omboue      GA     70.11         broken clouds
# 22       73              Khandyga      RU     76.73         broken clouds
# 23       76              Kamaishi      JP     75.60            light rain
# 24       79              Impfondo      CG     72.68       overcast clouds
# 25       84              Bengkulu      ID     74.70      scattered clouds
# 26       88           Yellowknife      CA     71.56         broken clouds
# 27       89            Shenjiamen      CN     79.25       overcast clouds
# 28       94             Flin Flon      CA     75.04          thunderstorm
# 29      105                Bonthe      SL     75.40  heavy intensity rain
# 30      106              Mbandaka      CD     72.01         broken clouds
# 31      110                Avarua      CK     77.05         broken clouds
# 32      119              Katsuura      JP     75.63       overcast clouds
# 33      122             Champasak      LA     73.29       overcast clouds
# 34      127                Marawi      PH     74.89       overcast clouds
# 35      138               Pitimbu      BR     75.90      scattered clouds
# 36      149              Cabedelo      BR     75.96            few clouds
# 37      152                Albion      US     75.38             clear sky
# 38      156                Kenora      CA     74.37         broken clouds
# 39      171               Maumere      ID     79.54         broken clouds
# 40      174    Hilton Head Island      US     77.00      scattered clouds
# 41      176                Acarau      BR     78.78       overcast clouds
# 42      189                  Biak      ID     77.47         broken clouds
# 43      192         Castelnaudary      FR     72.77             clear sky
# 44      196               Tautira      PF     76.64         broken clouds
# 45      197                Kiunga      PG     76.77       overcast clouds
# 46      199                Beidao      CN     78.40       overcast clouds
# 47      213              Valdosta      US     75.15             clear sky
# 48      214            Carutapera      BR     74.61         broken clouds
# 49      217         Bambanglipuro      ID     75.63             clear sky
# 50      218               Aklavik      CA     71.74      scattered clouds
# 51      220             Caravelas      BR     70.38             clear sky
# 52      224                Ripoll      ES     70.43             clear sky
# 53      225               Mindelo      CV     73.40      scattered clouds
# 54      228               Itapora      BR     72.54             clear sky
# 55      230  Santo Antonio Do Ica      BR     73.85       overcast clouds
# 56      237      Pontes E Lacerda      BR     76.26      scattered clouds
# 57      238   Sao Raimundo Nonato      BR     72.73             clear sky
# 58      242     Sao Joao Da Barra      BR     72.07             clear sky
# 59      243              La Ronge      CA     75.65      scattered clouds
#
#         Lat       Lng                                         Hotel Name
# 0   64.8378 -147.7164       Westmark Fairbanks Hotel & Conference Center
# 1  -23.1203 -134.9692                                    People ThankYou
# 2   17.0151   54.0924           HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# 3    8.2000  -59.7833                           Monty Brooms Guest House
# 4   -9.8000 -139.0333                                        Villa Enata
# 5   -2.9022  -40.8411                                   Ilha Praia Hotel
# 6  -21.1353  -55.8300                                 Nioaque Novo Hotel
# 7   -0.7393  -90.3518                          Finch Bay Galapagos Hotel
# 8  -28.4696  -65.7852                       Amerian Catamarca Park Hotel
# 9  -21.2000 -175.2000                                Keleti Beach Resort
# 10  42.0970  -79.2353                     Hampton Inn & Suites Jamestown
# 11   4.3750   -7.7169                                        Screensaver
# 12  21.8000 -100.9333                                HOTEL MARIA NATALIA
# 13  32.6667  -17.1000                                     Hotel do Campo
# 14 -33.0153   27.9116                                            Tu Casa
# 15  14.9215  -23.5087                                      LT Aparthotel
# 16  19.8000   85.8500                    OYO 1577 Hotel Shree Hari Grand
# 17 -22.9661  -42.0278                                Pousada Porto Praia
# 18  20.3467  -74.4958                                    Hostal Rio Miel
# 19  16.7798  101.2422                                 บ้านวรฉัตร หล่มสัก
# 20  -5.6667  132.7500                                  Grand Vilia Hotel
# 21  -1.5746    9.2618                                        Hotel Olako
# 22  62.6667  135.6000                                           Apel'sin
# 23  39.2667  141.8833                           Hotel Route Inn Kamaishi
# 24   1.6381   18.0667                          Auberge La Place de Jules
# 25  -3.8004  102.2655                               Grage Hotel Bengkulu
# 26  62.4560 -114.3525                                 The Explorer Hotel
# 27  29.9576  122.2980             Jinjiang Inn Zhoushan Putuo Shenjiamen
# 28  54.7682 -101.8650                             Victoria Inn Flin Flon
# 29   7.5264  -12.5050                             Bonthe Holiday Village
# 30   0.0487   18.2603                               Guest House Epervier
# 31 -21.2078 -159.7750                                       Paradise Inn
# 32  35.1333  140.3000                            Katsuura Hotel Mikazuki
# 33  14.7500  106.0000                        Kiat Ngong Wetland BUNGALOW
# 34   7.9986  124.2928                               Derogongan Residence
# 35  -7.4706  -34.8086                                   Reserva do Abiaí
# 36  -6.9811  -34.8339                                  Pousada Camboinha
# 37  42.2431  -84.7530                         Days Inn by Wyndham Albion
# 38  49.8167  -94.4337                                 Maynard Lake Lodge
# 39  -8.6199  122.2111                                       Sylvia Hotel
# 40  32.2163  -80.7526                 Disney’s Hilton Head Island Resort
# 41  -2.8856  -40.1200                                   castelo pizzaria
# 42  -0.9131  122.8766                                     Penginapan Kim
# 43  43.3183    1.9545                    Hôtel-Restaurant Le Clos Fleuri
# 44 -17.7333 -149.1500                                       Pension Oaoa
# 45  -6.1219  141.2906                               Airport Lodge Kiunga
# 46  34.5686  105.8933  Shell Tianshui Maiji District Erma Road Walkin...
# 47  30.8327  -83.2785                     Courtyard by Marriott Valdosta
# 48  -1.1950  -46.0200                                             Lidera
# 49  -7.9500  110.2833                                         Puri Brata
# 50  68.2191 -135.0107                                        Aklavik Inn
# 51 -17.7125  -39.2481                             Pousada dos Navegantes
# 52  42.2006    2.1903                               Hotel Solana Del Ter
# 53  16.8901  -24.9804                                        Hotel Gaudi
# 54 -22.0799  -54.7874                                     Hotel Santa Fé
# 55  -3.1022  -67.9397                                   HOTEL AMAZON WAY
# 56 -15.2261  -59.3353                                      Hotel Bressan
# 57  -9.0153  -42.6994                                         Real Hotel
# 58 -21.6403  -41.0511                            Pousada Porto De Canoas
# 59  55.1001 -105.2842                              Northland Motor Hotel

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]=="Evanston"]
vacation_end = vacation_df.loc[vacation_df["City"]=="Evanston"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]=="Jamestown"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]=="Albion"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="Garden City"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], \
        vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], \
      vacation_start["Lng"].to_numpy()[0]

# %%
stop1 = vacation_stop1["Lat"].to_numpy()[0], \
        vacation_stop1["Lng"].to_numpy()[0]

# %%
stop2 = vacation_stop2["Lat"].to_numpy()[0], \
        vacation_stop2["Lng"].to_numpy()[0]

# %%
stop3 = vacation_stop3["Lat"].to_numpy()[0], \
        vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
city_itinerary1 = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode = 'DRIVING')

fig.add_layer(city_itinerary1)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
city_itinerary2 = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode = 'BICYCLING')

fig.add_layer(city_itinerary2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
city_itinerary3 = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode = 'WALKING')

fig.add_layer(city_itinerary3)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID         City Country  Max Temp Current Description      Lat  \
# 0      300     Evanston      US     76.10           clear sky  42.0411
# 1       34    Jamestown      US     70.52           clear sky  42.0970
# 2      152       Albion      US     75.38           clear sky  42.2431
# 3      315  Garden City      US     78.80               smoke  42.3256
#
#        Lng                                      Hotel Name
# 0 -87.6901  Hilton Garden Inn Chicago North Shore/Evanston
# 1 -79.2353                  Hampton Inn & Suites Jamestown
# 2 -84.7530                      Days Inn by Wyndham Albion
# 3 -83.3310                 Big Trees Mobile Home Community

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
city_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=city_info)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
