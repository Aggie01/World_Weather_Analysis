# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
#coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
   #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
    #      citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 631

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | acapulco
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | taoudenni
# Processing Record 4 of Set 1 | ancud
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | clyde river
# Processing Record 10 of Set 1 | edd
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | copiapo
# Processing Record 15 of Set 1 | kandrian
# Processing Record 16 of Set 1 | caravelas
# Processing Record 17 of Set 1 | bonavista
# Processing Record 18 of Set 1 | faridan
# City not found. Skipping...
# Processing Record 19 of Set 1 | urengoy
# Processing Record 20 of Set 1 | morondava
# Processing Record 21 of Set 1 | samarinda
# Processing Record 22 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 1 | sorland
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | itarema
# Processing Record 31 of Set 1 | inyonga
# Processing Record 32 of Set 1 | sitka
# Processing Record 33 of Set 1 | moindou
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | ternate
# Processing Record 36 of Set 1 | port-cartier
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | willmar
# Processing Record 39 of Set 1 | barra
# Processing Record 40 of Set 1 | byron bay
# Processing Record 41 of Set 1 | san patricio
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | whitehaven
# Processing Record 44 of Set 1 | talnakh
# Processing Record 45 of Set 1 | tsagan aman
# Processing Record 46 of Set 1 | zhengjiatun
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | vagay
# Processing Record 1 of Set 2 | vila franca do campo
# Processing Record 2 of Set 2 | parras
# City not found. Skipping...
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | rio tercero
# Processing Record 5 of Set 2 | riyadh
# Processing Record 6 of Set 2 | nouadhibou
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | lompoc
# Processing Record 11 of Set 2 | bartlesville
# Processing Record 12 of Set 2 | leningradskiy
# Processing Record 13 of Set 2 | matay
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | corowa
# Processing Record 16 of Set 2 | port hardy
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | srednekolymsk
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | west bay
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | paamiut
# Processing Record 24 of Set 2 | vilhena
# Processing Record 25 of Set 2 | casper
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | cobija
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | portland
# Processing Record 30 of Set 2 | pepel
# Processing Record 31 of Set 2 | mugur-aksy
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | muros
# Processing Record 34 of Set 2 | atuntaqui
# Processing Record 35 of Set 2 | yen bai
# Processing Record 36 of Set 2 | yurty
# Processing Record 37 of Set 2 | khor
# Processing Record 38 of Set 2 | kharan
# Processing Record 39 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | jalu
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | isangel
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 2 | narsaq
# Processing Record 47 of Set 2 | ushtobe
# Processing Record 48 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | cockburn town
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | constantine
# Processing Record 3 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | turukhansk
# Processing Record 6 of Set 3 | bonwapitse
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | gashua
# Processing Record 11 of Set 3 | qasigiannguit
# Processing Record 12 of Set 3 | tuy hoa
# Processing Record 13 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 3 | axim
# Processing Record 15 of Set 3 | kuryk
# Processing Record 16 of Set 3 | puri
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | bulgan
# Processing Record 19 of Set 3 | tezu
# Processing Record 20 of Set 3 | chaman
# Processing Record 21 of Set 3 | salta
# Processing Record 22 of Set 3 | praia da vitoria
# Processing Record 23 of Set 3 | yantal
# Processing Record 24 of Set 3 | wucheng
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | pakokku
# Processing Record 27 of Set 3 | pangnirtung
# Processing Record 28 of Set 3 | nyurba
# Processing Record 29 of Set 3 | ibotirama
# Processing Record 30 of Set 3 | ariguani
# Processing Record 31 of Set 3 | masakin
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | airai
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | siderno
# Processing Record 36 of Set 3 | vestmanna
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | guozhen
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | almeirim
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | joshimath
# Processing Record 44 of Set 3 | nuuk
# Processing Record 45 of Set 3 | vardo
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | dikson
# Processing Record 48 of Set 3 | hobart
# Processing Record 49 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 3 | vao
# Processing Record 1 of Set 4 | camargo
# Processing Record 2 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 3 of Set 4 | adrar
# Processing Record 4 of Set 4 | shkotovo-26
# City not found. Skipping...
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | fochville
# Processing Record 7 of Set 4 | tuatapere
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | kudat
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | west odessa
# Processing Record 12 of Set 4 | dordrecht
# Processing Record 13 of Set 4 | ust-barguzin
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | mpongwe
# Processing Record 16 of Set 4 | albany
# Processing Record 17 of Set 4 | bongandanga
# Processing Record 18 of Set 4 | bud
# Processing Record 19 of Set 4 | kieta
# Processing Record 20 of Set 4 | vastervik
# City not found. Skipping...
# Processing Record 21 of Set 4 | fairbanks
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | barrhead
# Processing Record 24 of Set 4 | micheweni
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | saint-pierre
# Processing Record 27 of Set 4 | aquin
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 4 | goderich
# Processing Record 30 of Set 4 | tingrela
# City not found. Skipping...
# Processing Record 31 of Set 4 | villa carlos paz
# Processing Record 32 of Set 4 | coquimbo
# Processing Record 33 of Set 4 | makakilo city
# Processing Record 34 of Set 4 | victoria point
# Processing Record 35 of Set 4 | berdigestyakh
# Processing Record 36 of Set 4 | ambunti
# Processing Record 37 of Set 4 | zinder
# Processing Record 38 of Set 4 | shagonar
# Processing Record 39 of Set 4 | masvingo
# Processing Record 40 of Set 4 | chokurdakh
# Processing Record 41 of Set 4 | kosh-agach
# Processing Record 42 of Set 4 | bam
# Processing Record 43 of Set 4 | tucuman
# Processing Record 44 of Set 4 | houston
# Processing Record 45 of Set 4 | sobolevo
# Processing Record 46 of Set 4 | luau
# Processing Record 47 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 4 | durango
# Processing Record 49 of Set 4 | caraquet
# Processing Record 50 of Set 4 | georgetown
# Processing Record 1 of Set 5 | mendi
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | kodiak
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | coihaique
# Processing Record 6 of Set 5 | ambon
# Processing Record 7 of Set 5 | rurrenabaque
# Processing Record 8 of Set 5 | asau
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | koslan
# Processing Record 11 of Set 5 | eston
# Processing Record 12 of Set 5 | san cristobal
# Processing Record 13 of Set 5 | college
# Processing Record 14 of Set 5 | kavieng
# Processing Record 15 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 5 | cleveland
# Processing Record 17 of Set 5 | ambilobe
# Processing Record 18 of Set 5 | bantou
# Processing Record 19 of Set 5 | merauke
# Processing Record 20 of Set 5 | eugene
# Processing Record 21 of Set 5 | oranjemund
# Processing Record 22 of Set 5 | pogranichnyy
# Processing Record 23 of Set 5 | belmonte
# Processing Record 24 of Set 5 | port moresby
# Processing Record 25 of Set 5 | izmaylovo
# Processing Record 26 of Set 5 | nyimba
# Processing Record 27 of Set 5 | muli
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 5 | sudak
# Processing Record 31 of Set 5 | puerto escondido
# Processing Record 32 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 5 | qaqortoq
# Processing Record 34 of Set 5 | tarakan
# Processing Record 35 of Set 5 | la libertad
# Processing Record 36 of Set 5 | westport
# Processing Record 37 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 5 | feira de santana
# Processing Record 39 of Set 5 | oranjestad
# Processing Record 40 of Set 5 | saint-philippe
# Processing Record 41 of Set 5 | lamar
# Processing Record 42 of Set 5 | mar del plata
# Processing Record 43 of Set 5 | lasa
# Processing Record 44 of Set 5 | bandarbeyla
# Processing Record 45 of Set 5 | pisco
# Processing Record 46 of Set 5 | nelson bay
# Processing Record 47 of Set 5 | te anau
# Processing Record 48 of Set 5 | jumla
# Processing Record 49 of Set 5 | kapaa
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | esperance
# Processing Record 2 of Set 6 | gucheng
# Processing Record 3 of Set 6 | mutoko
# Processing Record 4 of Set 6 | mimoso do sul
# Processing Record 5 of Set 6 | umbauba
# Processing Record 6 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 7 of Set 6 | roald
# Processing Record 8 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 6 | castlemaine
# Processing Record 10 of Set 6 | la rioja
# Processing Record 11 of Set 6 | bardiyah
# Processing Record 12 of Set 6 | healdsburg
# Processing Record 13 of Set 6 | pauini
# Processing Record 14 of Set 6 | vila velha
# Processing Record 15 of Set 6 | buraydah
# Processing Record 16 of Set 6 | batagay
# Processing Record 17 of Set 6 | plattsburgh
# Processing Record 18 of Set 6 | bauchi
# Processing Record 19 of Set 6 | necochea
# Processing Record 20 of Set 6 | susehri
# Processing Record 21 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 6 | egvekinot
# Processing Record 23 of Set 6 | bela vista
# Processing Record 24 of Set 6 | mahibadhoo
# Processing Record 25 of Set 6 | wencheng
# Processing Record 26 of Set 6 | ponta do sol
# Processing Record 27 of Set 6 | dunedin
# Processing Record 28 of Set 6 | aksu
# Processing Record 29 of Set 6 | la maddalena
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | vilyuysk
# Processing Record 32 of Set 6 | gamba
# Processing Record 33 of Set 6 | grand gaube
# Processing Record 34 of Set 6 | muridke
# Processing Record 35 of Set 6 | tiksi
# Processing Record 36 of Set 6 | san juan
# Processing Record 37 of Set 6 | quelimane
# Processing Record 38 of Set 6 | ospitaletto
# Processing Record 39 of Set 6 | bijar
# Processing Record 40 of Set 6 | teahupoo
# Processing Record 41 of Set 6 | partizanskoye
# Processing Record 42 of Set 6 | krasnouralsk
# Processing Record 43 of Set 6 | carnarvon
# Processing Record 44 of Set 6 | port blair
# Processing Record 45 of Set 6 | temuco
# Processing Record 46 of Set 6 | mehamn
# Processing Record 47 of Set 6 | neuquen
# Processing Record 48 of Set 6 | tuktoyaktuk
# Processing Record 49 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 50 of Set 6 | santa maria
# Processing Record 1 of Set 7 | brindisi
# Processing Record 2 of Set 7 | praia
# Processing Record 3 of Set 7 | bafoulabe
# Processing Record 4 of Set 7 | redmond
# Processing Record 5 of Set 7 | mehran
# Processing Record 6 of Set 7 | menongue
# Processing Record 7 of Set 7 | prieska
# Processing Record 8 of Set 7 | tucurui
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | flin flon
# Processing Record 11 of Set 7 | nyagan
# Processing Record 12 of Set 7 | rio grande city
# Processing Record 13 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 7 | cherskiy
# Processing Record 15 of Set 7 | kerteh
# City not found. Skipping...
# Processing Record 16 of Set 7 | kruisfontein
# Processing Record 17 of Set 7 | kiama
# Processing Record 18 of Set 7 | pingliang
# Processing Record 19 of Set 7 | edson
# Processing Record 20 of Set 7 | provideniya
# Processing Record 21 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 7 | ilo
# Processing Record 23 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 7 | syracuse
# Processing Record 25 of Set 7 | shitanjing
# Processing Record 26 of Set 7 | beringovskiy
# Processing Record 27 of Set 7 | abu zabad
# Processing Record 28 of Set 7 | qui nhon
# Processing Record 29 of Set 7 | yeppoon
# Processing Record 30 of Set 7 | dourados
# Processing Record 31 of Set 7 | tulum
# Processing Record 32 of Set 7 | alice springs
# Processing Record 33 of Set 7 | rognan
# Processing Record 34 of Set 7 | abu kamal
# Processing Record 35 of Set 7 | monrovia
# Processing Record 36 of Set 7 | normandin
# Processing Record 37 of Set 7 | lom sak
# Processing Record 38 of Set 7 | sehithwa
# Processing Record 39 of Set 7 | ballina
# Processing Record 40 of Set 7 | klaksvik
# Processing Record 41 of Set 7 | palu
# Processing Record 42 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 7 | bilibino
# Processing Record 44 of Set 7 | acu
# Processing Record 45 of Set 7 | biltine
# Processing Record 46 of Set 7 | kiunga
# Processing Record 47 of Set 7 | malinovoye ozero
# Processing Record 48 of Set 7 | palmer
# Processing Record 49 of Set 7 | kahului
# Processing Record 50 of Set 7 | hasaki
# Processing Record 1 of Set 8 | grindavik
# Processing Record 2 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 8 | dubovka
# Processing Record 4 of Set 8 | nioki
# Processing Record 5 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 6 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 8 | scarborough
# Processing Record 8 of Set 8 | urfa
# City not found. Skipping...
# Processing Record 9 of Set 8 | vysokogornyy
# Processing Record 10 of Set 8 | molchanovo
# Processing Record 11 of Set 8 | alyangula
# Processing Record 12 of Set 8 | guerrero negro
# Processing Record 13 of Set 8 | bukama
# Processing Record 14 of Set 8 | kamaishi
# Processing Record 15 of Set 8 | talcahuano
# Processing Record 16 of Set 8 | mackay
# Processing Record 17 of Set 8 | saint-francois
# Processing Record 18 of Set 8 | choa saidan shah
# Processing Record 19 of Set 8 | lazaro cardenas
# Processing Record 20 of Set 8 | hay river
# Processing Record 21 of Set 8 | pitkyaranta
# Processing Record 22 of Set 8 | sabalgarh
# Processing Record 23 of Set 8 | broken hill
# Processing Record 24 of Set 8 | ahmadpur east
# Processing Record 25 of Set 8 | urumqi
# Processing Record 26 of Set 8 | moussoro
# Processing Record 27 of Set 8 | gilgil
# City not found. Skipping...
# Processing Record 28 of Set 8 | talas
# Processing Record 29 of Set 8 | pankrushikha
# Processing Record 30 of Set 8 | karanja
# Processing Record 31 of Set 8 | beyneu
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | safaga
# Processing Record 34 of Set 8 | cayenne
# Processing Record 35 of Set 8 | urupes
# Processing Record 36 of Set 8 | jhawarian
# Processing Record 37 of Set 8 | vinh
# Processing Record 38 of Set 8 | limbang
# Processing Record 39 of Set 8 | naze
# Processing Record 40 of Set 8 | honningsvag
# Processing Record 41 of Set 8 | martapura
# Processing Record 42 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 8 | fortuna
# Processing Record 45 of Set 8 | ladushkin
# Processing Record 46 of Set 8 | mwinilunga
# Processing Record 47 of Set 8 | hofn
# Processing Record 48 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 8 | marks
# Processing Record 50 of Set 8 | telemaco borba
# Processing Record 1 of Set 9 | lensk
# Processing Record 2 of Set 9 | ketchikan
# Processing Record 3 of Set 9 | baturaja
# Processing Record 4 of Set 9 | karachi
# Processing Record 5 of Set 9 | marsabit
# Processing Record 6 of Set 9 | palana
# Processing Record 7 of Set 9 | laguna
# Processing Record 8 of Set 9 | coahuayana
# Processing Record 9 of Set 9 | pemangkat
# Processing Record 10 of Set 9 | portage
# Processing Record 11 of Set 9 | prado
# Processing Record 12 of Set 9 | rhymney
# Processing Record 13 of Set 9 | ayan
# Processing Record 14 of Set 9 | fukue
# Processing Record 15 of Set 9 | norman wells
# Processing Record 16 of Set 9 | oktyabrskoye
# Processing Record 17 of Set 9 | biak
# Processing Record 18 of Set 9 | belaya gora
# Processing Record 19 of Set 9 | bukachacha
# Processing Record 20 of Set 9 | porto santo
# Processing Record 21 of Set 9 | atasu
# Processing Record 22 of Set 9 | olga
# Processing Record 23 of Set 9 | palaikastron
# Processing Record 24 of Set 9 | totma
# Processing Record 25 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 9 | mitu
# Processing Record 27 of Set 9 | epernay
# Processing Record 28 of Set 9 | waingapu
# Processing Record 29 of Set 9 | ialibu
# Processing Record 30 of Set 9 | batagay-alyta
# Processing Record 31 of Set 9 | marawi
# Processing Record 32 of Set 9 | port-gentil
# Processing Record 33 of Set 9 | haines junction
# Processing Record 34 of Set 9 | tamasopo
# Processing Record 35 of Set 9 | walvis bay
# Processing Record 36 of Set 9 | rancho palos verdes
# Processing Record 37 of Set 9 | taft
# Processing Record 38 of Set 9 | esil
# Processing Record 39 of Set 9 | manaquiri
# Processing Record 40 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 41 of Set 9 | long xuyen
# Processing Record 42 of Set 9 | buchanan
# Processing Record 43 of Set 9 | tornio
# Processing Record 44 of Set 9 | samana
# Processing Record 45 of Set 9 | alta floresta
# Processing Record 46 of Set 9 | korla
# Processing Record 47 of Set 9 | kargasok
# Processing Record 48 of Set 9 | chapais
# Processing Record 49 of Set 9 | namtsy
# Processing Record 50 of Set 9 | dicabisagan
# Processing Record 1 of Set 10 | marzuq
# Processing Record 2 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 10 | yar-sale
# Processing Record 4 of Set 10 | borba
# Processing Record 5 of Set 10 | salinas
# Processing Record 6 of Set 10 | maningrida
# Processing Record 7 of Set 10 | verkhoyansk
# Processing Record 8 of Set 10 | ilulissat
# Processing Record 9 of Set 10 | champerico
# Processing Record 10 of Set 10 | storforshei
# Processing Record 11 of Set 10 | rivera
# Processing Record 12 of Set 10 | svetlaya
# Processing Record 13 of Set 10 | rocha
# Processing Record 14 of Set 10 | kavaratti
# Processing Record 15 of Set 10 | tessalit
# Processing Record 16 of Set 10 | jishou
# Processing Record 17 of Set 10 | bintulu
# Processing Record 18 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 10 | linxia
# Processing Record 20 of Set 10 | iqaluit
# Processing Record 21 of Set 10 | northam
# Processing Record 22 of Set 10 | alofi
# Processing Record 23 of Set 10 | the valley
# Processing Record 24 of Set 10 | buritizeiro
# Processing Record 25 of Set 10 | marsh harbour
# Processing Record 26 of Set 10 | inongo
# Processing Record 27 of Set 10 | roebourne
# Processing Record 28 of Set 10 | bathsheba
# Processing Record 29 of Set 10 | albury
# Processing Record 30 of Set 10 | codrington
# Processing Record 31 of Set 10 | karratha
# Processing Record 32 of Set 10 | teontepec
# Processing Record 33 of Set 10 | sungaipenuh
# Processing Record 34 of Set 10 | sao jose da coroa grande
# Processing Record 35 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 10 | ca mau
# Processing Record 37 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 38 of Set 10 | kidal
# Processing Record 39 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 10 | arya
# Processing Record 41 of Set 10 | paita
# Processing Record 42 of Set 10 | port keats
# Processing Record 43 of Set 10 | talakan
# Processing Record 44 of Set 10 | port augusta
# Processing Record 45 of Set 10 | mandiana
# Processing Record 46 of Set 10 | nhulunbuy
# Processing Record 47 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 10 | nalut
# Processing Record 49 of Set 10 | gobabis
# Processing Record 50 of Set 10 | rawson
# Processing Record 1 of Set 11 | kologriv
# Processing Record 2 of Set 11 | juneau
# Processing Record 3 of Set 11 | portoferraio
# Processing Record 4 of Set 11 | baherden
# Processing Record 5 of Set 11 | mayo
# Processing Record 6 of Set 11 | sainte-rose
# Processing Record 7 of Set 11 | matara
# Processing Record 8 of Set 11 | tutoia
# Processing Record 9 of Set 11 | great falls
# Processing Record 10 of Set 11 | uttarkashi
# Processing Record 11 of Set 11 | chany
# Processing Record 12 of Set 11 | griffith
# Processing Record 13 of Set 11 | kaniama
# Processing Record 14 of Set 11 | nemuro
# Processing Record 15 of Set 11 | bairiki
# Processing Record 16 of Set 11 | katsuura
# Processing Record 17 of Set 11 | hof
# Processing Record 18 of Set 11 | namibe
# Processing Record 19 of Set 11 | bereznik
# Processing Record 20 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 11 | suzaka
# Processing Record 22 of Set 11 | hanzhong
# Processing Record 23 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 11 | batouri
# Processing Record 25 of Set 11 | lakatoro
# Processing Record 26 of Set 11 | tocopilla
# Processing Record 27 of Set 11 | tomigusuku
# Processing Record 28 of Set 11 | marsa matruh
# Processing Record 29 of Set 11 | liaoyang
# Processing Record 30 of Set 11 | cochrane
# Processing Record 31 of Set 11 | owando
# Processing Record 32 of Set 11 | leshukonskoye
# Processing Record 33 of Set 11 | tahta
# Processing Record 34 of Set 11 | kharovsk
# Processing Record 35 of Set 11 | gari
# Processing Record 36 of Set 11 | hirara
# Processing Record 37 of Set 11 | makungu
# Processing Record 38 of Set 11 | ambanja
# Processing Record 39 of Set 11 | villa rica
# Processing Record 40 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 41 of Set 11 | jieshi
# Processing Record 42 of Set 11 | doha
# Processing Record 43 of Set 11 | zhigansk
# Processing Record 44 of Set 11 | drovyanaya
# Processing Record 45 of Set 11 | lethem
# Processing Record 46 of Set 11 | porto seguro
# Processing Record 47 of Set 11 | saint-augustin
# Processing Record 48 of Set 11 | touros
# Processing Record 49 of Set 11 | seoul
# Processing Record 50 of Set 11 | kyra
# Processing Record 1 of Set 12 | sao joao da barra
# Processing Record 2 of Set 12 | utrecht
# Processing Record 3 of Set 12 | aktau
# Processing Record 4 of Set 12 | macapa
# Processing Record 5 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 6 of Set 12 | quang ngai
# Processing Record 7 of Set 12 | nizwa
# Processing Record 8 of Set 12 | husavik
# Processing Record 9 of Set 12 | takoradi
# Processing Record 10 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 11 of Set 12 | bekhtery
# Processing Record 12 of Set 12 | gloversville
# Processing Record 13 of Set 12 | pizarro
# Processing Record 14 of Set 12 | xinyang
# Processing Record 15 of Set 12 | jansath
# Processing Record 16 of Set 12 | vadso
# Processing Record 17 of Set 12 | impfondo
# Processing Record 18 of Set 12 | havoysund
# Processing Record 19 of Set 12 | esmeralda
# Processing Record 20 of Set 12 | suez
# Processing Record 21 of Set 12 | ouadda
# Processing Record 22 of Set 12 | kaitangata
# Processing Record 23 of Set 12 | ahipara
# Processing Record 24 of Set 12 | waw
# Processing Record 25 of Set 12 | burley
# Processing Record 26 of Set 12 | shouguang
# Processing Record 27 of Set 12 | lakes entrance
# Processing Record 28 of Set 12 | hamilton
# Processing Record 29 of Set 12 | chulumani
# Processing Record 30 of Set 12 | inhambane
# Processing Record 31 of Set 12 | tacuarembo
# Processing Record 32 of Set 12 | balikpapan
# Processing Record 33 of Set 12 | tshikapa
# Processing Record 34 of Set 12 | avera
# Processing Record 35 of Set 12 | jizan
# Processing Record 36 of Set 12 | manicore
# Processing Record 37 of Set 12 | xining
# Processing Record 38 of Set 12 | suffolk
# Processing Record 39 of Set 12 | meulaboh
# Processing Record 40 of Set 12 | gander
# Processing Record 41 of Set 12 | bubaque
# Processing Record 42 of Set 12 | duluth
# Processing Record 43 of Set 12 | padang
# Processing Record 44 of Set 12 | praxedis guerrero
# Processing Record 45 of Set 12 | chihuahua
# Processing Record 46 of Set 12 | tual
# Processing Record 47 of Set 12 | canico
# Processing Record 48 of Set 12 | ust-tsilma
# Processing Record 49 of Set 12 | bonfim
# Processing Record 50 of Set 12 | lugovoy
# Processing Record 1 of Set 13 | barao de melgaco
# Processing Record 2 of Set 13 | saint cloud
# Processing Record 3 of Set 13 | horsham
# Processing Record 4 of Set 13 | cilaos
# Processing Record 5 of Set 13 | den helder
# Processing Record 6 of Set 13 | umm lajj
# Processing Record 7 of Set 13 | orangeville
# Processing Record 8 of Set 13 | rawah
# Processing Record 9 of Set 13 | alcains
# Processing Record 10 of Set 13 | tairua
# Processing Record 11 of Set 13 | honiara
# Processing Record 12 of Set 13 | banda aceh
# Processing Record 13 of Set 13 | bitung
# Processing Record 14 of Set 13 | ouegoa
# Processing Record 15 of Set 13 | foligno
# Processing Record 16 of Set 13 | angoche
# Processing Record 17 of Set 13 | san carlos de bariloche
# Processing Record 18 of Set 13 | cabo san lucas
# Processing Record 19 of Set 13 | ormara
# Processing Record 20 of Set 13 | goundam
# Processing Record 21 of Set 13 | mareeba
# Processing Record 22 of Set 13 | bonthe
# Processing Record 23 of Set 13 | mangrol
# Processing Record 24 of Set 13 | dukat
# Processing Record 25 of Set 13 | wanlaweyn
# Processing Record 26 of Set 13 | hohhot
# Processing Record 27 of Set 13 | dingle
# Processing Record 28 of Set 13 | foca
# Processing Record 29 of Set 13 | aqtobe
# Processing Record 30 of Set 13 | suchiapa
# Processing Record 31 of Set 13 | gat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Acapulco  16.8634  -99.8901     86.72        65          71        6.60
# 1      Rikitea -23.1203 -134.9692     74.91        77          78       21.83
# 2    Taoudenni  22.6783   -3.9836    109.63         8           0        8.84
# 3        Ancud -41.8697  -73.8203     45.23        81         100       17.31
# 4     Bengkulu  -3.8004  102.2655     74.43        89           2        3.74
# 5       Atuona  -9.8000 -139.0333     76.96        81          60       15.61
# 6        Bluff -46.6000  168.3333     44.80        89         100       30.67
# 7      Mataura -46.1927  168.8643     44.47        96         100        8.93
# 8  Clyde River  70.4692  -68.5914     43.03        75          75        6.91
# 9          Edd  13.9297   41.6925     89.74        68         100       10.54
#
#   Country                 Date
# 0      MX  2022-07-08 18:44:11
# 1      PF  2022-07-08 18:44:26
# 2      ML  2022-07-08 18:46:48
# 3      CL  2022-07-08 18:46:52
# 4      ID  2022-07-08 18:45:47
# 5      PF  2022-07-08 18:44:29
# 6      NZ  2022-07-08 18:44:30
# 7      NZ  2022-07-08 18:44:31
# 8      CA  2022-07-08 18:49:11
# 9      ER  2022-07-08 18:49:19

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
