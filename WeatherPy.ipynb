# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
#coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
   #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
    #      citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 599

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | golden
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | dingle
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | cootamundra
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | praya
# Processing Record 8 of Set 1 | berlevag
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | tyup
# Processing Record 11 of Set 1 | tuatapere
# Processing Record 12 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 1 | yulara
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | severnyy
# Processing Record 23 of Set 1 | fonte boa
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | maceio
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | soto la marina
# Processing Record 29 of Set 1 | tahta
# Processing Record 30 of Set 1 | kavieng
# Processing Record 31 of Set 1 | mobaye
# Processing Record 32 of Set 1 | suntar
# Processing Record 33 of Set 1 | mount gambier
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | hualmay
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | avera
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | santa maria
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | sambava
# Processing Record 44 of Set 1 | ahipara
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | tiznit
# Processing Record 47 of Set 1 | grand gaube
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | santa rosalia
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | muisne
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | luderitz
# Processing Record 5 of Set 2 | dolores
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | puerto ayacucho
# Processing Record 8 of Set 2 | san quintin
# Processing Record 9 of Set 2 | les cayes
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | mount isa
# Processing Record 12 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | wexford
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | shubarkuduk
# Processing Record 19 of Set 2 | grenville
# Processing Record 20 of Set 2 | juanacatlan
# Processing Record 21 of Set 2 | mirnyy
# Processing Record 22 of Set 2 | garmsar
# Processing Record 23 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 2 | krasnoselkup
# Processing Record 25 of Set 2 | kamphaeng phet
# Processing Record 26 of Set 2 | torbay
# Processing Record 27 of Set 2 | maniwaki
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | canico
# Processing Record 30 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 31 of Set 2 | rawson
# Processing Record 32 of Set 2 | denpasar
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | calvinia
# Processing Record 36 of Set 2 | cabedelo
# Processing Record 37 of Set 2 | shimoda
# Processing Record 38 of Set 2 | bengkalis
# City not found. Skipping...
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | hvolsvollur
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | husavik
# Processing Record 43 of Set 2 | abha
# Processing Record 44 of Set 2 | reyes
# Processing Record 45 of Set 2 | yeniseysk
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | seymchan
# Processing Record 48 of Set 2 | coihaique
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | tasiilaq
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | peniche
# Processing Record 3 of Set 3 | gunjur
# Processing Record 4 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 5 of Set 3 | komsomolskiy
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | guadalupe y calvo
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 3 | atar
# Processing Record 12 of Set 3 | caravelas
# Processing Record 13 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | lavrentiya
# Processing Record 16 of Set 3 | klaksvik
# Processing Record 17 of Set 3 | fairbanks
# Processing Record 18 of Set 3 | kargil
# Processing Record 19 of Set 3 | vestmannaeyjar
# Processing Record 20 of Set 3 | shangrao
# Processing Record 21 of Set 3 | leshukonskoye
# Processing Record 22 of Set 3 | jaunjelgava
# Processing Record 23 of Set 3 | bathsheba
# Processing Record 24 of Set 3 | tiksi
# Processing Record 25 of Set 3 | san patricio
# Processing Record 26 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 27 of Set 3 | ozernovskiy
# Processing Record 28 of Set 3 | yuza
# Processing Record 29 of Set 3 | batsfjord
# Processing Record 30 of Set 3 | aborlan
# Processing Record 31 of Set 3 | geraldton
# Processing Record 32 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 3 | itoman
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | banda aceh
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | dhidhdhoo
# Processing Record 38 of Set 3 | hesperia
# Processing Record 39 of Set 3 | alice springs
# Processing Record 40 of Set 3 | gao
# Processing Record 41 of Set 3 | east london
# Processing Record 42 of Set 3 | pimentel
# Processing Record 43 of Set 3 | kasangulu
# Processing Record 44 of Set 3 | takab
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | matagami
# Processing Record 48 of Set 3 | constitucion
# Processing Record 49 of Set 3 | mangrol
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | waipawa
# Processing Record 2 of Set 4 | omboue
# Processing Record 3 of Set 4 | vidra
# Processing Record 4 of Set 4 | sabang
# Processing Record 5 of Set 4 | sorland
# Processing Record 6 of Set 4 | altar
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | westport
# Processing Record 9 of Set 4 | tawang
# Processing Record 10 of Set 4 | puerto ayora
# Processing Record 11 of Set 4 | billings
# Processing Record 12 of Set 4 | sulangan
# Processing Record 13 of Set 4 | yellowknife
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | moba
# Processing Record 16 of Set 4 | saedinenie
# Processing Record 17 of Set 4 | saint-joseph
# Processing Record 18 of Set 4 | yinchuan
# Processing Record 19 of Set 4 | bunol
# Processing Record 20 of Set 4 | kondopoga
# Processing Record 21 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 22 of Set 4 | tucurui
# Processing Record 23 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 4 | lokosovo
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | kondinskoye
# Processing Record 27 of Set 4 | milingimbi
# City not found. Skipping...
# Processing Record 28 of Set 4 | bubaque
# Processing Record 29 of Set 4 | san cristobal
# Processing Record 30 of Set 4 | mukhen
# Processing Record 31 of Set 4 | banyo
# Processing Record 32 of Set 4 | trofors
# Processing Record 33 of Set 4 | lazaro cardenas
# Processing Record 34 of Set 4 | wladyslawowo
# Processing Record 35 of Set 4 | izhma
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | mayumba
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | nicoya
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | bilma
# Processing Record 42 of Set 4 | lundazi
# Processing Record 43 of Set 4 | kloulklubed
# Processing Record 44 of Set 4 | bang saphan
# Processing Record 45 of Set 4 | matay
# Processing Record 46 of Set 4 | coquimbo
# Processing Record 47 of Set 4 | chokurdakh
# Processing Record 48 of Set 4 | vila franca do campo
# Processing Record 49 of Set 4 | qaqortoq
# Processing Record 50 of Set 4 | provideniya
# Processing Record 1 of Set 5 | boguchany
# Processing Record 2 of Set 5 | belmonte
# Processing Record 3 of Set 5 | launceston
# Processing Record 4 of Set 5 | wangqing
# Processing Record 5 of Set 5 | tekeli
# Processing Record 6 of Set 5 | severnoye
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | lata
# Processing Record 9 of Set 5 | beringovskiy
# Processing Record 10 of Set 5 | pacific grove
# Processing Record 11 of Set 5 | leopold
# Processing Record 12 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 5 | grindavik
# Processing Record 14 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 15 of Set 5 | vao
# Processing Record 16 of Set 5 | bull savanna
# Processing Record 17 of Set 5 | hecun
# Processing Record 18 of Set 5 | lappeenranta
# Processing Record 19 of Set 5 | novyy urengoy
# Processing Record 20 of Set 5 | burnie
# Processing Record 21 of Set 5 | lasem
# Processing Record 22 of Set 5 | lethem
# Processing Record 23 of Set 5 | kathmandu
# Processing Record 24 of Set 5 | banyumas
# Processing Record 25 of Set 5 | castro
# Processing Record 26 of Set 5 | newcastle
# Processing Record 27 of Set 5 | teya
# Processing Record 28 of Set 5 | capitao poco
# Processing Record 29 of Set 5 | wanning
# Processing Record 30 of Set 5 | kruisfontein
# Processing Record 31 of Set 5 | taoudenni
# Processing Record 32 of Set 5 | hasaki
# Processing Record 33 of Set 5 | sarangani
# Processing Record 34 of Set 5 | bereda
# Processing Record 35 of Set 5 | nantucket
# Processing Record 36 of Set 5 | jacareacanga
# Processing Record 37 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 5 | bethel
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | agadez
# Processing Record 41 of Set 5 | los llanos de aridane
# Processing Record 42 of Set 5 | aswan
# Processing Record 43 of Set 5 | seoul
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 5 | honningsvag
# Processing Record 47 of Set 5 | bambous virieux
# Processing Record 48 of Set 5 | chapais
# Processing Record 49 of Set 5 | isangel
# Processing Record 50 of Set 5 | dunedin
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | sonoita
# Processing Record 3 of Set 6 | abrego
# Processing Record 4 of Set 6 | port elizabeth
# Processing Record 5 of Set 6 | rocha
# Processing Record 6 of Set 6 | praia
# Processing Record 7 of Set 6 | harper
# Processing Record 8 of Set 6 | sibolga
# Processing Record 9 of Set 6 | hamilton
# Processing Record 10 of Set 6 | barcelos
# Processing Record 11 of Set 6 | vila velha
# Processing Record 12 of Set 6 | kutum
# Processing Record 13 of Set 6 | tete
# Processing Record 14 of Set 6 | zhangye
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | saskylakh
# Processing Record 17 of Set 6 | camacha
# Processing Record 18 of Set 6 | samarai
# Processing Record 19 of Set 6 | jalingo
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | requena
# Processing Record 22 of Set 6 | arraial do cabo
# Processing Record 23 of Set 6 | pereira barreto
# Processing Record 24 of Set 6 | saint-pierre
# Processing Record 25 of Set 6 | nizhniy kuranakh
# Processing Record 26 of Set 6 | cabo san lucas
# Processing Record 27 of Set 6 | aklavik
# Processing Record 28 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | olafsvik
# Processing Record 30 of Set 6 | sao filipe
# Processing Record 31 of Set 6 | lao cai
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | raudeberg
# Processing Record 35 of Set 6 | alyangula
# Processing Record 36 of Set 6 | turukhansk
# Processing Record 37 of Set 6 | stephenville
# Processing Record 38 of Set 6 | ancud
# Processing Record 39 of Set 6 | tonj
# Processing Record 40 of Set 6 | pangnirtung
# Processing Record 41 of Set 6 | araouane
# Processing Record 42 of Set 6 | pedasi
# Processing Record 43 of Set 6 | ukiah
# Processing Record 44 of Set 6 | ostrovnoy
# Processing Record 45 of Set 6 | genhe
# Processing Record 46 of Set 6 | yanam
# Processing Record 47 of Set 6 | ibb
# Processing Record 48 of Set 6 | durazno
# Processing Record 49 of Set 6 | bengkulu
# Processing Record 50 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 7 | muros
# Processing Record 2 of Set 7 | boueni
# Processing Record 3 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 7 | kodinsk
# Processing Record 5 of Set 7 | carutapera
# Processing Record 6 of Set 7 | abu samrah
# Processing Record 7 of Set 7 | semey
# Processing Record 8 of Set 7 | faya
# Processing Record 9 of Set 7 | pontianak
# Processing Record 10 of Set 7 | gandajika
# Processing Record 11 of Set 7 | jieshou
# Processing Record 12 of Set 7 | moerai
# Processing Record 13 of Set 7 | scarborough
# Processing Record 14 of Set 7 | kamina
# Processing Record 15 of Set 7 | nishihara
# Processing Record 16 of Set 7 | esil
# Processing Record 17 of Set 7 | saint-georges
# Processing Record 18 of Set 7 | grand bank
# Processing Record 19 of Set 7 | nuuk
# Processing Record 20 of Set 7 | galle
# Processing Record 21 of Set 7 | loukhi
# Processing Record 22 of Set 7 | borovoy
# Processing Record 23 of Set 7 | pisco
# Processing Record 24 of Set 7 | miri
# Processing Record 25 of Set 7 | cefalu
# Processing Record 26 of Set 7 | saint-francois
# Processing Record 27 of Set 7 | huarmey
# Processing Record 28 of Set 7 | saint anthony
# Processing Record 29 of Set 7 | atasu
# Processing Record 30 of Set 7 | narsaq
# Processing Record 31 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 7 | paita
# Processing Record 33 of Set 7 | tillabery
# City not found. Skipping...
# Processing Record 34 of Set 7 | oksfjord
# Processing Record 35 of Set 7 | baripada
# Processing Record 36 of Set 7 | tadine
# Processing Record 37 of Set 7 | gohad
# Processing Record 38 of Set 7 | tamiahua
# Processing Record 39 of Set 7 | codrington
# Processing Record 40 of Set 7 | choszczno
# Processing Record 41 of Set 7 | trincomalee
# Processing Record 42 of Set 7 | sento se
# City not found. Skipping...
# Processing Record 43 of Set 7 | wukari
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | whitehorse
# Processing Record 46 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 7 | paramonga
# Processing Record 48 of Set 7 | sibu
# Processing Record 49 of Set 7 | uzunovo
# Processing Record 50 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 8 | acajutla
# Processing Record 2 of Set 8 | shar
# Processing Record 3 of Set 8 | havoysund
# Processing Record 4 of Set 8 | manta
# Processing Record 5 of Set 8 | mehamn
# Processing Record 6 of Set 8 | elizabeth city
# Processing Record 7 of Set 8 | upington
# Processing Record 8 of Set 8 | dudinka
# Processing Record 9 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 10 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 8 | kelme
# Processing Record 12 of Set 8 | tura
# Processing Record 13 of Set 8 | vyssi brod
# Processing Record 14 of Set 8 | tashtagol
# Processing Record 15 of Set 8 | ucluelet
# Processing Record 16 of Set 8 | broome
# Processing Record 17 of Set 8 | dasoguz
# Processing Record 18 of Set 8 | semnan
# Processing Record 19 of Set 8 | hobyo
# Processing Record 20 of Set 8 | namibe
# Processing Record 21 of Set 8 | najran
# Processing Record 22 of Set 8 | metro
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | siva
# Processing Record 25 of Set 8 | uruguaiana
# Processing Record 26 of Set 8 | san jeronimo
# Processing Record 27 of Set 8 | vieques
# Processing Record 28 of Set 8 | cherskiy
# Processing Record 29 of Set 8 | udaipura
# Processing Record 30 of Set 8 | rocky mountain house
# Processing Record 31 of Set 8 | canavieiras
# Processing Record 32 of Set 8 | pustoshka
# Processing Record 33 of Set 8 | terekli-mekteb
# Processing Record 34 of Set 8 | bac giang
# Processing Record 35 of Set 8 | siilinjarvi
# Processing Record 36 of Set 8 | santa fe
# Processing Record 37 of Set 8 | goksun
# Processing Record 38 of Set 8 | tilichiki
# Processing Record 39 of Set 8 | port macquarie
# Processing Record 40 of Set 8 | korfovskiy
# Processing Record 41 of Set 8 | izhevsk
# Processing Record 42 of Set 8 | nouakchott
# Processing Record 43 of Set 8 | ocampo
# Processing Record 44 of Set 8 | paralimni
# Processing Record 45 of Set 8 | kandrian
# Processing Record 46 of Set 8 | nioro
# Processing Record 47 of Set 8 | adrar
# Processing Record 48 of Set 8 | alakurtti
# Processing Record 49 of Set 8 | roebourne
# Processing Record 50 of Set 8 | lompoc
# Processing Record 1 of Set 9 | airai
# Processing Record 2 of Set 9 | madona
# Processing Record 3 of Set 9 | bandarbeyla
# Processing Record 4 of Set 9 | grand-lahou
# Processing Record 5 of Set 9 | mezen
# Processing Record 6 of Set 9 | kijang
# Processing Record 7 of Set 9 | port hedland
# Processing Record 8 of Set 9 | phichit
# Processing Record 9 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 9 | cururupu
# Processing Record 11 of Set 9 | great yarmouth
# Processing Record 12 of Set 9 | havre-saint-pierre
# Processing Record 13 of Set 9 | de land
# Processing Record 14 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 9 | margate
# Processing Record 16 of Set 9 | west wendover
# Processing Record 17 of Set 9 | karratha
# Processing Record 18 of Set 9 | atherton
# Processing Record 19 of Set 9 | manama
# Processing Record 20 of Set 9 | sangin
# Processing Record 21 of Set 9 | dinan
# Processing Record 22 of Set 9 | bonao
# Processing Record 23 of Set 9 | sydney
# Processing Record 24 of Set 9 | quatre cocos
# Processing Record 25 of Set 9 | tynset
# Processing Record 26 of Set 9 | pochutla
# Processing Record 27 of Set 9 | kushiro
# Processing Record 28 of Set 9 | jiazi
# Processing Record 29 of Set 9 | veshenskaya
# Processing Record 30 of Set 9 | santiago de chuco
# Processing Record 31 of Set 9 | acapulco
# Processing Record 32 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 9 | cockburn town
# Processing Record 34 of Set 9 | axixa do tocantins
# City not found. Skipping...
# Processing Record 35 of Set 9 | aginskoye
# Processing Record 36 of Set 9 | basco
# Processing Record 37 of Set 9 | mexico
# Processing Record 38 of Set 9 | tautira
# Processing Record 39 of Set 9 | riaba
# City not found. Skipping...
# Processing Record 40 of Set 9 | monrovia
# Processing Record 41 of Set 9 | visnes
# Processing Record 42 of Set 9 | wasco
# Processing Record 43 of Set 9 | south valley
# Processing Record 44 of Set 9 | emerald
# Processing Record 45 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 9 | rio grande
# Processing Record 48 of Set 9 | auki
# Processing Record 49 of Set 9 | saldanha
# Processing Record 50 of Set 9 | iralaya
# Processing Record 1 of Set 10 | richards bay
# Processing Record 2 of Set 10 | dire dawa
# Processing Record 3 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 10 | kungurtug
# Processing Record 5 of Set 10 | kashi
# Processing Record 6 of Set 10 | urumqi
# Processing Record 7 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 8 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 9 of Set 10 | kattivakkam
# Processing Record 10 of Set 10 | le mars
# Processing Record 11 of Set 10 | vardo
# Processing Record 12 of Set 10 | helong
# Processing Record 13 of Set 10 | fafe
# Processing Record 14 of Set 10 | aripuana
# Processing Record 15 of Set 10 | waw
# Processing Record 16 of Set 10 | sharan
# Processing Record 17 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 18 of Set 10 | weihe
# Processing Record 19 of Set 10 | karaton
# Processing Record 20 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 21 of Set 10 | vanimo
# Processing Record 22 of Set 10 | meulaboh
# Processing Record 23 of Set 10 | thunder bay
# Processing Record 24 of Set 10 | taksimo
# Processing Record 25 of Set 10 | tagusao
# Processing Record 26 of Set 10 | hannibal
# Processing Record 27 of Set 10 | hun
# Processing Record 28 of Set 10 | lagoa
# Processing Record 29 of Set 10 | velez-malaga
# Processing Record 30 of Set 10 | soyo
# Processing Record 31 of Set 10 | porto walter
# Processing Record 32 of Set 10 | guano
# Processing Record 33 of Set 10 | inirida
# Processing Record 34 of Set 10 | yuanping
# Processing Record 35 of Set 10 | pudozh
# Processing Record 36 of Set 10 | ilulissat
# Processing Record 37 of Set 10 | senno
# Processing Record 38 of Set 10 | alamosa
# Processing Record 39 of Set 10 | sistranda
# Processing Record 40 of Set 10 | sidi bu zayd
# City not found. Skipping...
# Processing Record 41 of Set 10 | brumadinho
# Processing Record 42 of Set 10 | masterton
# Processing Record 43 of Set 10 | namatanai
# Processing Record 44 of Set 10 | hofn
# Processing Record 45 of Set 10 | port lincoln
# Processing Record 46 of Set 10 | zabaykalsk
# Processing Record 47 of Set 10 | dibulla
# Processing Record 48 of Set 10 | ferrol
# Processing Record 49 of Set 10 | belomorsk
# Processing Record 50 of Set 10 | newport
# Processing Record 1 of Set 11 | vetralla
# Processing Record 2 of Set 11 | virginia beach
# Processing Record 3 of Set 11 | maldonado
# Processing Record 4 of Set 11 | daura
# Processing Record 5 of Set 11 | sayyan
# Processing Record 6 of Set 11 | panjab
# Processing Record 7 of Set 11 | sugod
# Processing Record 8 of Set 11 | cortez
# Processing Record 9 of Set 11 | kjollefjord
# Processing Record 10 of Set 11 | telenesti
# Processing Record 11 of Set 11 | san rafael
# Processing Record 12 of Set 11 | luena
# Processing Record 13 of Set 11 | livingston
# Processing Record 14 of Set 11 | saurimo
# Processing Record 15 of Set 11 | nelson bay
# Processing Record 16 of Set 11 | katangli
# Processing Record 17 of Set 11 | kamenka
# Processing Record 18 of Set 11 | port loko
# Processing Record 19 of Set 11 | maracacume
# Processing Record 20 of Set 11 | katsuura
# Processing Record 21 of Set 11 | kingori
# Processing Record 22 of Set 11 | kawalu
# Processing Record 23 of Set 11 | kenora
# Processing Record 24 of Set 11 | eyrarbakki
# Processing Record 25 of Set 11 | la ronge
# Processing Record 26 of Set 11 | arantangi
# Processing Record 27 of Set 11 | henties bay
# Processing Record 28 of Set 11 | shebunino
# Processing Record 29 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 11 | arlit
# Processing Record 31 of Set 11 | ville-marie
# Processing Record 32 of Set 11 | labuhan
# Processing Record 33 of Set 11 | javanrud
# Processing Record 34 of Set 11 | salalah
# Processing Record 35 of Set 11 | bowen
# Processing Record 36 of Set 11 | mogadishu
# Processing Record 37 of Set 11 | digboi
# Processing Record 38 of Set 11 | bilibino
# Processing Record 39 of Set 11 | talnakh
# Processing Record 40 of Set 11 | talcahuano
# Processing Record 41 of Set 11 | ayr
# Processing Record 42 of Set 11 | whyalla
# Processing Record 43 of Set 11 | ozinki
# Processing Record 44 of Set 11 | scottsbluff
# Processing Record 45 of Set 11 | iqaluit
# Processing Record 46 of Set 11 | cayenne
# Processing Record 47 of Set 11 | khatra
# Processing Record 48 of Set 11 | havelock
# Processing Record 49 of Set 11 | ishigaki
# Processing Record 50 of Set 11 | panaba
# Processing Record 1 of Set 12 | pandan
# Processing Record 2 of Set 12 | marmaris
# Processing Record 3 of Set 12 | emba
