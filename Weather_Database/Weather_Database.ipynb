# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | vila
# Processing Record 3 of Set 1 | antofagasta
# Processing Record 4 of Set 1 | mattru
# Processing Record 5 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | coari
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | klaksvik
# Processing Record 11 of Set 1 | tahoua
# Processing Record 12 of Set 1 | northam
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | raudeberg
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | quatre cocos
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | galdar
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | saldanha
# Processing Record 34 of Set 1 | ancud
# Processing Record 35 of Set 1 | birin
# Processing Record 36 of Set 1 | muravlenko
# Processing Record 37 of Set 1 | innisfail
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | portland
# Processing Record 40 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 1 | aranos
# Processing Record 42 of Set 1 | vila velha
# Processing Record 43 of Set 1 | meulaboh
# Processing Record 44 of Set 1 | clyde river
# Processing Record 45 of Set 1 | clyde
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | ostrovnoy
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | sa kaeo
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | isangel
# Processing Record 5 of Set 2 | murud
# Processing Record 6 of Set 2 | sao joao da barra
# Processing Record 7 of Set 2 | zhigansk
# Processing Record 8 of Set 2 | lucapa
# Processing Record 9 of Set 2 | wilmington
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | sao miguel do araguaia
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | ayan
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | rio gallegos
# Processing Record 20 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 21 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 2 | la rioja
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | mount gambier
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | paamiut
# Processing Record 28 of Set 2 | grand gaube
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | partenit
# Processing Record 38 of Set 2 | puerto escondido
# Processing Record 39 of Set 2 | souillac
# Processing Record 40 of Set 2 | kushiro
# Processing Record 41 of Set 2 | pacific grove
# Processing Record 42 of Set 2 | quilali
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | geraldton
# Processing Record 45 of Set 2 | port keats
# Processing Record 46 of Set 2 | cabo san lucas
# Processing Record 47 of Set 2 | vestmannaeyjar
# Processing Record 48 of Set 2 | ayr
# Processing Record 49 of Set 2 | san policarpo
# Processing Record 50 of Set 2 | half moon bay
# Processing Record 1 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | bungu
# Processing Record 5 of Set 3 | bend
# Processing Record 6 of Set 3 | basco
# Processing Record 7 of Set 3 | banepa
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | katsuura
# Processing Record 10 of Set 3 | jamame
# Processing Record 11 of Set 3 | chaa-khol
# City not found. Skipping...
# Processing Record 12 of Set 3 | ballina
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | wawa
# Processing Record 16 of Set 3 | taikang
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | nikolayevsk-na-amure
# Processing Record 20 of Set 3 | diffa
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | aykhal
# Processing Record 23 of Set 3 | purpe
# Processing Record 24 of Set 3 | terra santa
# Processing Record 25 of Set 3 | severo-kurilsk
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | port shepstone
# Processing Record 29 of Set 3 | codrington
# Processing Record 30 of Set 3 | chumikan
# Processing Record 31 of Set 3 | hualmay
# Processing Record 32 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | inyonga
# Processing Record 35 of Set 3 | hofn
# Processing Record 36 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 3 | bonfim
# Processing Record 39 of Set 3 | chimbote
# Processing Record 40 of Set 3 | valera
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | porbandar
# Processing Record 43 of Set 3 | cherskiy
# Processing Record 44 of Set 3 | hasaki
# Processing Record 45 of Set 3 | yatou
# Processing Record 46 of Set 3 | hamilton
# Processing Record 47 of Set 3 | conakry
# Processing Record 48 of Set 3 | lagos
# Processing Record 49 of Set 3 | severnyy
# Processing Record 50 of Set 3 | iwanai
# Processing Record 1 of Set 4 | brandenburg
# Processing Record 2 of Set 4 | barceloneta
# Processing Record 3 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 4 | broken hill
# Processing Record 5 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 6 of Set 4 | harper
# Processing Record 7 of Set 4 | changzhou
# Processing Record 8 of Set 4 | lompoc
# Processing Record 9 of Set 4 | rosarito
# Processing Record 10 of Set 4 | tawang
# Processing Record 11 of Set 4 | pringsewu
# Processing Record 12 of Set 4 | bredasdorp
# Processing Record 13 of Set 4 | nam tha
# City not found. Skipping...
# Processing Record 14 of Set 4 | provideniya
# Processing Record 15 of Set 4 | morondava
# Processing Record 16 of Set 4 | kirkwall
# Processing Record 17 of Set 4 | fort nelson
# Processing Record 18 of Set 4 | pangkalanbuun
# Processing Record 19 of Set 4 | calama
# Processing Record 20 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 4 | vila franca do campo
# Processing Record 22 of Set 4 | rocha
# Processing Record 23 of Set 4 | maumere
# Processing Record 24 of Set 4 | sokoni
# Processing Record 25 of Set 4 | imeni zhelyabova
# Processing Record 26 of Set 4 | opuwo
# Processing Record 27 of Set 4 | zhuozhou
# City not found. Skipping...
# Processing Record 28 of Set 4 | samdari
# Processing Record 29 of Set 4 | manaure
# Processing Record 30 of Set 4 | tomatlan
# Processing Record 31 of Set 4 | ribas do rio pardo
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | orgun
# City not found. Skipping...
# Processing Record 34 of Set 4 | luino
# Processing Record 35 of Set 4 | roma
# Processing Record 36 of Set 4 | cockburn town
# Processing Record 37 of Set 4 | moree
# Processing Record 38 of Set 4 | ibadan
# Processing Record 39 of Set 4 | winslow
# Processing Record 40 of Set 4 | bhatkal
# Processing Record 41 of Set 4 | north battleford
# Processing Record 42 of Set 4 | airai
# Processing Record 43 of Set 4 | kovylkino
# Processing Record 44 of Set 4 | apastovo
# Processing Record 45 of Set 4 | vilhena
# Processing Record 46 of Set 4 | norman wells
# Processing Record 47 of Set 4 | kadoma
# Processing Record 48 of Set 4 | eseka
# Processing Record 49 of Set 4 | caliling
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | ivankiv
# Processing Record 2 of Set 5 | taoudenni
# Processing Record 3 of Set 5 | ilek
# Processing Record 4 of Set 5 | makokou
# Processing Record 5 of Set 5 | ahipara
# Processing Record 6 of Set 5 | nizhnevartovsk
# Processing Record 7 of Set 5 | bratsk
# Processing Record 8 of Set 5 | sosnovo-ozerskoye
# Processing Record 9 of Set 5 | puga
# Processing Record 10 of Set 5 | methoni
# Processing Record 11 of Set 5 | nianzishan
# Processing Record 12 of Set 5 | whitecourt
# Processing Record 13 of Set 5 | emirdag
# Processing Record 14 of Set 5 | diu
# Processing Record 15 of Set 5 | abu zabad
# Processing Record 16 of Set 5 | shache
# Processing Record 17 of Set 5 | omsukchan
# Processing Record 18 of Set 5 | loikaw
# Processing Record 19 of Set 5 | sarangani
# Processing Record 20 of Set 5 | ovalle
# Processing Record 21 of Set 5 | rio grande
# Processing Record 22 of Set 5 | marsaxlokk
# Processing Record 23 of Set 5 | mata
# Processing Record 24 of Set 5 | waddan
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | port hardy
# Processing Record 27 of Set 5 | laguna
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | calderitas
# Processing Record 30 of Set 5 | pochutla
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | mahon
# Processing Record 33 of Set 5 | puerto narino
# Processing Record 34 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 5 | sioux lookout
# Processing Record 36 of Set 5 | tocopilla
# Processing Record 37 of Set 5 | labuhan
# Processing Record 38 of Set 5 | coquimbo
# Processing Record 39 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 5 | korsakov
# Processing Record 41 of Set 5 | port lincoln
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | vega de alatorre
# Processing Record 45 of Set 5 | tikapur
# Processing Record 46 of Set 5 | ambalavao
# Processing Record 47 of Set 5 | vallenar
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | dali
# Processing Record 50 of Set 5 | cordoba
# Processing Record 1 of Set 6 | srivardhan
# Processing Record 2 of Set 6 | lasa
# Processing Record 3 of Set 6 | egvekinot
# Processing Record 4 of Set 6 | cernatesti
# Processing Record 5 of Set 6 | ust-omchug
# Processing Record 6 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 6 | tessalit
# Processing Record 8 of Set 6 | cairns
# Processing Record 9 of Set 6 | tineo
# Processing Record 10 of Set 6 | caluquembe
# Processing Record 11 of Set 6 | biak
# Processing Record 12 of Set 6 | point pleasant
# Processing Record 13 of Set 6 | gibara
# Processing Record 14 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 6 | surovikino
# Processing Record 16 of Set 6 | crotone
# Processing Record 17 of Set 6 | svetlaya
# Processing Record 18 of Set 6 | barcelos
# Processing Record 19 of Set 6 | lyubytino
# Processing Record 20 of Set 6 | hovd
# Processing Record 21 of Set 6 | majene
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | ambulu
# Processing Record 24 of Set 6 | pangoa
# Processing Record 25 of Set 6 | urengoy
# Processing Record 26 of Set 6 | lavrentiya
# Processing Record 27 of Set 6 | arrifes
# Processing Record 28 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 6 | tulun
# Processing Record 30 of Set 6 | usogorsk
# Processing Record 31 of Set 6 | iskateley
# Processing Record 32 of Set 6 | paramonga
# Processing Record 33 of Set 6 | ketchikan
# Processing Record 34 of Set 6 | sitka
# Processing Record 35 of Set 6 | churapcha
# Processing Record 36 of Set 6 | springdale
# Processing Record 37 of Set 6 | urucara
# Processing Record 38 of Set 6 | takoradi
# Processing Record 39 of Set 6 | karpathos
# Processing Record 40 of Set 6 | katherine
# Processing Record 41 of Set 6 | pinawa
# Processing Record 42 of Set 6 | noyabrsk
# Processing Record 43 of Set 6 | touros
# Processing Record 44 of Set 6 | southbridge
# Processing Record 45 of Set 6 | tautira
# Processing Record 46 of Set 6 | minab
# Processing Record 47 of Set 6 | queanbeyan
# Processing Record 48 of Set 6 | chapais
# Processing Record 49 of Set 6 | angola
# Processing Record 50 of Set 6 | imeni babushkina
# Processing Record 1 of Set 7 | indramayu
# Processing Record 2 of Set 7 | plettenberg bay
# Processing Record 3 of Set 7 | orangeburg
# Processing Record 4 of Set 7 | baiyin
# Processing Record 5 of Set 7 | coihaique
# Processing Record 6 of Set 7 | hohhot
# Processing Record 7 of Set 7 | husavik
# Processing Record 8 of Set 7 | san jeronimo
# Processing Record 9 of Set 7 | westport
# Processing Record 10 of Set 7 | rawson
# Processing Record 11 of Set 7 | axim
# Processing Record 12 of Set 7 | vardo
# Processing Record 13 of Set 7 | novaya mayna
# Processing Record 14 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 15 of Set 7 | acapulco
# Processing Record 16 of Set 7 | kastamonu
# Processing Record 17 of Set 7 | san quintin
# Processing Record 18 of Set 7 | luderitz
# Processing Record 19 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 20 of Set 7 | san juan
# Processing Record 21 of Set 7 | kenai
# Processing Record 22 of Set 7 | ambon
# Processing Record 23 of Set 7 | komsomolskiy
# Processing Record 24 of Set 7 | grindavik
# Processing Record 25 of Set 7 | kavaratti
# Processing Record 26 of Set 7 | ambilobe
# Processing Record 27 of Set 7 | sakakah
# Processing Record 28 of Set 7 | praia da vitoria
# Processing Record 29 of Set 7 | cape girardeau
# Processing Record 30 of Set 7 | gumia
# Processing Record 31 of Set 7 | road town
# Processing Record 32 of Set 7 | khandyga
# Processing Record 33 of Set 7 | mandal
# Processing Record 34 of Set 7 | dong hoi
# Processing Record 35 of Set 7 | yulara
# Processing Record 36 of Set 7 | walvis bay
# Processing Record 37 of Set 7 | mecca
# Processing Record 38 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 7 | ringebu
# Processing Record 40 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 41 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 7 | flin flon
# Processing Record 43 of Set 7 | victoria
# Processing Record 44 of Set 7 | san cristobal
# Processing Record 45 of Set 7 | nome
# Processing Record 46 of Set 7 | korla
# Processing Record 47 of Set 7 | shirvan
# Processing Record 48 of Set 7 | necochea
# Processing Record 49 of Set 7 | cabedelo
# Processing Record 50 of Set 7 | yellowknife
# Processing Record 1 of Set 8 | port-cartier
# Processing Record 2 of Set 8 | san-pedro
# Processing Record 3 of Set 8 | matagami
# Processing Record 4 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 8 | talaya
# Processing Record 6 of Set 8 | impfondo
# Processing Record 7 of Set 8 | kitakata
# Processing Record 8 of Set 8 | anuchino
# Processing Record 9 of Set 8 | mangla
# Processing Record 10 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 11 of Set 8 | srednekolymsk
# Processing Record 12 of Set 8 | pouebo
# Processing Record 13 of Set 8 | maraa
# Processing Record 14 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 8 | matara
# Processing Record 16 of Set 8 | port augusta
# Processing Record 17 of Set 8 | davila
# Processing Record 18 of Set 8 | frutal
# Processing Record 19 of Set 8 | krasnoselkup
# Processing Record 20 of Set 8 | acarau
# Processing Record 21 of Set 8 | libreville
# Processing Record 22 of Set 8 | maniitsoq
# Processing Record 23 of Set 8 | puerto leguizamo
# Processing Record 24 of Set 8 | baturaja
# Processing Record 25 of Set 8 | taganak
# Processing Record 26 of Set 8 | kloulklubed
# Processing Record 27 of Set 8 | farah
# Processing Record 28 of Set 8 | inverell
# Processing Record 29 of Set 8 | kysyl-syr
# Processing Record 30 of Set 8 | buchanan
# Processing Record 31 of Set 8 | nikel
# Processing Record 32 of Set 8 | fortuna
# Processing Record 33 of Set 8 | gagnoa
# Processing Record 34 of Set 8 | muros
# Processing Record 35 of Set 8 | santa clara
# Processing Record 36 of Set 8 | gweta
# Processing Record 37 of Set 8 | muchkapskiy
# Processing Record 38 of Set 8 | lillooet
# Processing Record 39 of Set 8 | leshukonskoye
# Processing Record 40 of Set 8 | seymchan
# Processing Record 41 of Set 8 | karatuzskoye
# Processing Record 42 of Set 8 | gorontalo
# Processing Record 43 of Set 8 | mildura
# Processing Record 44 of Set 8 | shingu
# Processing Record 45 of Set 8 | thames
# Processing Record 46 of Set 8 | thompson
# Processing Record 47 of Set 8 | pasni
# Processing Record 48 of Set 8 | erzin
# Processing Record 49 of Set 8 | saint-augustin
# Processing Record 50 of Set 8 | cidreira
# Processing Record 1 of Set 9 | narsaq
# Processing Record 2 of Set 9 | vrangel
# Processing Record 3 of Set 9 | richards bay
# Processing Record 4 of Set 9 | llangefni
# Processing Record 5 of Set 9 | saint-denis
# Processing Record 6 of Set 9 | teknaf
# Processing Record 7 of Set 9 | karangasem
# Processing Record 8 of Set 9 | sergeyevka
# Processing Record 9 of Set 9 | tam ky
# Processing Record 10 of Set 9 | faya
# Processing Record 11 of Set 9 | irece
# Processing Record 12 of Set 9 | kattivakkam
# Processing Record 13 of Set 9 | ust-kuyga
# Processing Record 14 of Set 9 | tura
# Processing Record 15 of Set 9 | loukhi
# Processing Record 16 of Set 9 | mayumba
# Processing Record 17 of Set 9 | onega
# Processing Record 18 of Set 9 | high level
# Processing Record 19 of Set 9 | merauke
# Processing Record 20 of Set 9 | vanderhoof
# Processing Record 21 of Set 9 | lata
# Processing Record 22 of Set 9 | nalut
# Processing Record 23 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 9 | bereznik
# Processing Record 25 of Set 9 | sao gabriel da cachoeira
# Processing Record 26 of Set 9 | ghanzi
# Processing Record 27 of Set 9 | maragogi
# Processing Record 28 of Set 9 | tukrah
# Processing Record 29 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 9 | nanchang
# Processing Record 32 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 9 | liseleje
# Processing Record 34 of Set 9 | tibacuy
# Processing Record 35 of Set 9 | guilin
# Processing Record 36 of Set 9 | upernavik
# Processing Record 37 of Set 9 | burnie
# Processing Record 38 of Set 9 | capao da canoa
# Processing Record 39 of Set 9 | filingue
# Processing Record 40 of Set 9 | san rafael
# Processing Record 41 of Set 9 | waw
# Processing Record 42 of Set 9 | conceicao do mato dentro
# Processing Record 43 of Set 9 | turayf
# Processing Record 44 of Set 9 | timberlake
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | woodward
# Processing Record 47 of Set 9 | chinsali
# Processing Record 48 of Set 9 | mananjary
# Processing Record 49 of Set 9 | safaga
# Processing Record 50 of Set 9 | pamplona
# Processing Record 1 of Set 10 | ratnagiri
# Processing Record 2 of Set 10 | boyolangu
# Processing Record 3 of Set 10 | jadu
# Processing Record 4 of Set 10 | scarborough
# Processing Record 5 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 10 | ishigaki
# Processing Record 7 of Set 10 | nichinan
# Processing Record 8 of Set 10 | beringovskiy
# Processing Record 9 of Set 10 | leningradskiy
# Processing Record 10 of Set 10 | arroio grande
# Processing Record 11 of Set 10 | cabinda
# Processing Record 12 of Set 10 | dingle
# Processing Record 13 of Set 10 | cobija
# Processing Record 14 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 10 | nalgonda
# Processing Record 18 of Set 10 | ewa beach
# Processing Record 19 of Set 10 | te anau
# Processing Record 20 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 10 | carora
# Processing Record 22 of Set 10 | almoloya
# Processing Record 23 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 24 of Set 10 | buraydah
# Processing Record 25 of Set 10 | goderich
# Processing Record 26 of Set 10 | nanakuli
# Processing Record 27 of Set 10 | port-gentil
# Processing Record 28 of Set 10 | stornoway
# Processing Record 29 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 10 | yurimaguas
# Processing Record 31 of Set 10 | dudinka
# Processing Record 32 of Set 10 | vitim
# Processing Record 33 of Set 10 | bukachacha
# Processing Record 34 of Set 10 | sept-iles
# Processing Record 35 of Set 10 | tori fatehpur
# Processing Record 36 of Set 10 | chandbali
# Processing Record 37 of Set 10 | cayenne
# Processing Record 38 of Set 10 | kangaatsiaq
# Processing Record 39 of Set 10 | vung tau
# Processing Record 40 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | haines junction
# Processing Record 42 of Set 10 | moranbah
# Processing Record 43 of Set 10 | mount isa
# Processing Record 44 of Set 10 | liverpool
# Processing Record 45 of Set 10 | christchurch
# Processing Record 46 of Set 10 | anadyr
# Processing Record 47 of Set 10 | nola
# Processing Record 48 of Set 10 | east london
# Processing Record 49 of Set 10 | bull savanna
# Processing Record 50 of Set 10 | dunedin
# Processing Record 1 of Set 11 | adrar
# Processing Record 2 of Set 11 | arlit
# Processing Record 3 of Set 11 | port alberni
# Processing Record 4 of Set 11 | seoul
# Processing Record 5 of Set 11 | arvika
# Processing Record 6 of Set 11 | dunda
# Processing Record 7 of Set 11 | sinnamary
# Processing Record 8 of Set 11 | tres lagoas
# Processing Record 9 of Set 11 | coahuayana
# Processing Record 10 of Set 11 | coruripe
# Processing Record 11 of Set 11 | ruteng
# Processing Record 12 of Set 11 | north bend
# Processing Record 13 of Set 11 | teya
# Processing Record 14 of Set 11 | atlantic beach
# Processing Record 15 of Set 11 | maldonado
# Processing Record 16 of Set 11 | makat
# Processing Record 17 of Set 11 | san patricio
# Processing Record 18 of Set 11 | presidencia roque saenz pena
# Processing Record 19 of Set 11 | praya
# Processing Record 20 of Set 11 | novo aripuana
# Processing Record 21 of Set 11 | chany
# Processing Record 22 of Set 11 | hambantota
# Processing Record 23 of Set 11 | ongandjera
# Processing Record 24 of Set 11 | shieli
# Processing Record 25 of Set 11 | karratha
# Processing Record 26 of Set 11 | ilhabela
# Processing Record 27 of Set 11 | nsanje
# Processing Record 28 of Set 11 | ust-kan
# Processing Record 29 of Set 11 | lagoa
# Processing Record 30 of Set 11 | mamallapuram
# Processing Record 31 of Set 11 | menongue
# Processing Record 32 of Set 11 | fairbanks
# Processing Record 33 of Set 11 | sur
# Processing Record 34 of Set 11 | tamandare
# Processing Record 35 of Set 11 | luleburgaz
# Processing Record 36 of Set 11 | hamada
# Processing Record 37 of Set 11 | chabahar
# Processing Record 38 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 11 | auki
# Processing Record 40 of Set 11 | hami
# Processing Record 41 of Set 11 | marienburg
# Processing Record 42 of Set 11 | sable-sur-sarthe
# Processing Record 43 of Set 11 | flinders
# Processing Record 44 of Set 11 | miraflores
# Processing Record 45 of Set 11 | kavieng
# Processing Record 46 of Set 11 | berlevag
# Processing Record 47 of Set 11 | polewali
# Processing Record 48 of Set 11 | marawi
# Processing Record 49 of Set 11 | chardara
# Processing Record 50 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 12 | ulaangom
# Processing Record 2 of Set 12 | banda aceh
# Processing Record 3 of Set 12 | ugoofaaru
# Processing Record 4 of Set 12 | kindia
# Processing Record 5 of Set 12 | nakhodka
# Processing Record 6 of Set 12 | valparaiso
# Processing Record 7 of Set 12 | aswan
# Processing Record 8 of Set 12 | mercedes
# Processing Record 9 of Set 12 | celestun
# Processing Record 10 of Set 12 | kurilsk
# Processing Record 11 of Set 12 | narasannapeta
# Processing Record 12 of Set 12 | elizabeth city
# Processing Record 13 of Set 12 | pa sang
# Processing Record 14 of Set 12 | bundaberg
# Processing Record 15 of Set 12 | samarai
# Processing Record 16 of Set 12 | ormara
# Processing Record 17 of Set 12 | wewak
# Processing Record 18 of Set 12 | humaita
# Processing Record 19 of Set 12 | ibra
# Processing Record 20 of Set 12 | camargo
# Processing Record 21 of Set 12 | kamaishi
# Processing Record 22 of Set 12 | kaoma
# Processing Record 23 of Set 12 | kalmunai
# Processing Record 24 of Set 12 | gisborne
# Processing Record 25 of Set 12 | digha
# Processing Record 26 of Set 12 | aguimes
# Processing Record 27 of Set 12 | danielskuil
# Processing Record 28 of Set 12 | chara
# Processing Record 29 of Set 12 | ostra
# Processing Record 30 of Set 12 | melfi
# Processing Record 31 of Set 12 | lazaro cardenas
# Processing Record 32 of Set 12 | metro
# Processing Record 33 of Set 12 | mancora
# Processing Record 34 of Set 12 | yuxia
# Processing Record 35 of Set 12 | coffs harbour
# Processing Record 36 of Set 12 | anloga
# Processing Record 37 of Set 12 | kirakira
# Processing Record 38 of Set 12 | imbituba
# Processing Record 39 of Set 12 | yar-sale
# Processing Record 40 of Set 12 | kaupanger
# Processing Record 41 of Set 12 | luancheng
# Processing Record 42 of Set 12 | palmer
# Processing Record 43 of Set 12 | nouadhibou
# Processing Record 44 of Set 12 | superior
# Processing Record 45 of Set 12 | ixtapa
# Processing Record 46 of Set 12 | sidney
# Processing Record 47 of Set 12 | atar
# Processing Record 48 of Set 12 | byron bay
# Processing Record 49 of Set 12 | kamenka
# Processing Record 50 of Set 12 | mehamn
# Processing Record 1 of Set 13 | kaihua
# Processing Record 2 of Set 13 | gharghoda
# Processing Record 3 of Set 13 | aasiaat
# Processing Record 4 of Set 13 | rosetta
# Processing Record 5 of Set 13 | salvador
# Processing Record 6 of Set 13 | ngunguru
# Processing Record 7 of Set 13 | key west
# Processing Record 8 of Set 13 | gayny
# Processing Record 9 of Set 13 | colomi
# Processing Record 10 of Set 13 | belaya gora
# Processing Record 11 of Set 13 | ginda
# Processing Record 12 of Set 13 | asau
# Processing Record 13 of Set 13 | andenes
# Processing Record 14 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 13 | kagoro
# Processing Record 16 of Set 13 | tucurui
# Processing Record 17 of Set 13 | norden
# Processing Record 18 of Set 13 | poum
# Processing Record 19 of Set 13 | khao yoi
# Processing Record 20 of Set 13 | alta floresta
# Processing Record 21 of Set 13 | monclova
# Processing Record 22 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 23 of Set 13 | miri
# Processing Record 24 of Set 13 | fukue
# Processing Record 25 of Set 13 | koumac
# Processing Record 26 of Set 13 | tual
# Processing Record 27 of Set 13 | gat
# Processing Record 28 of Set 13 | nhulunbuy
# Processing Record 29 of Set 13 | tuatapere
# Processing Record 30 of Set 13 | jardim
# Processing Record 31 of Set 13 | esperance
# Processing Record 32 of Set 13 | natal
# Processing Record 33 of Set 13 | pangnirtung
# Processing Record 34 of Set 13 | lakes entrance
# Processing Record 35 of Set 13 | tahara
# Processing Record 36 of Set 13 | normandin
# Processing Record 37 of Set 13 | ustrzyki dolne
# Processing Record 38 of Set 13 | manyana
# Processing Record 39 of Set 13 | sibolga
# Processing Record 40 of Set 13 | kieta
# Processing Record 41 of Set 13 | caravelas
# Processing Record 42 of Set 13 | tilichiki
# Processing Record 43 of Set 13 | riaba
# City not found. Skipping...
# Processing Record 44 of Set 13 | manado
# Processing Record 45 of Set 13 | los llanos de aridane
# Processing Record 46 of Set 13 | wajid
# Processing Record 47 of Set 13 | tombouctou
# Processing Record 48 of Set 13 | stawell
# Processing Record 49 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 50 of Set 13 | clearwater
# Processing Record 1 of Set 14 | namatanai
# Processing Record 2 of Set 14 | borama
# City not found. Skipping...
# Processing Record 3 of Set 14 | mahibadhoo
# Processing Record 4 of Set 14 | carbonia
# Processing Record 5 of Set 14 | nanortalik
# Processing Record 6 of Set 14 | lakeside
# Processing Record 7 of Set 14 | kotdwara
# Processing Record 8 of Set 14 | carnot
# Processing Record 9 of Set 14 | castilho
# Processing Record 10 of Set 14 | moyale
# Processing Record 11 of Set 14 | bay roberts
# Processing Record 12 of Set 14 | nizwa
# Processing Record 13 of Set 14 | tarauaca
# Processing Record 14 of Set 14 | fort atkinson
# Processing Record 15 of Set 14 | lerwick
# Processing Record 16 of Set 14 | oranjemund
# Processing Record 17 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 14 | roros
# Processing Record 20 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 14 | salalah
# Processing Record 22 of Set 14 | omboue
# Processing Record 23 of Set 14 | kununurra
# Processing Record 24 of Set 14 | gravdal
# Processing Record 25 of Set 14 | verkhoyansk
# Processing Record 26 of Set 14 | redlands
# Processing Record 27 of Set 14 | mwene-ditu
# Processing Record 28 of Set 14 | shymkent
# Processing Record 29 of Set 14 | krasnoborsk
# Processing Record 30 of Set 14 | belmonte
# Processing Record 31 of Set 14 | kachiry
# Processing Record 32 of Set 14 | adre
# Processing Record 33 of Set 14 | aklavik
# Processing Record 34 of Set 14 | copiapo
# Processing Record 35 of Set 14 | china
# Processing Record 36 of Set 14 | constitucion
# Processing Record 37 of Set 14 | panara
# Processing Record 38 of Set 14 | waipawa
# Processing Record 39 of Set 14 | sorland
# Processing Record 40 of Set 14 | werda
# Processing Record 41 of Set 14 | pustoshka
# Processing Record 42 of Set 14 | abomsa
# Processing Record 43 of Set 14 | beidao
# Processing Record 44 of Set 14 | malakisi
# City not found. Skipping...
# Processing Record 45 of Set 14 | loncoche
# Processing Record 46 of Set 14 | mitu
# Processing Record 47 of Set 14 | rapid valley
# Processing Record 48 of Set 14 | port hawkesbury
# Processing Record 49 of Set 14 | midland
# Processing Record 50 of Set 14 | alencon
# Processing Record 1 of Set 15 | vao
# Processing Record 2 of Set 15 | sukhumi
# Processing Record 3 of Set 15 | dahuk
# Processing Record 4 of Set 15 | aden
# Processing Record 5 of Set 15 | nishihara
# Processing Record 6 of Set 15 | nuuk
# Processing Record 7 of Set 15 | la ronge
# Processing Record 8 of Set 15 | maceio
# Processing Record 9 of Set 15 | vilyuysk
# Processing Record 10 of Set 15 | marck
# Processing Record 11 of Set 15 | ust-maya
# Processing Record 12 of Set 15 | gizo
# Processing Record 13 of Set 15 | gimli
# Processing Record 14 of Set 15 | oktyabrskiy
# Processing Record 15 of Set 15 | nyurba
# Processing Record 16 of Set 15 | katobu
# Processing Record 17 of Set 15 | alenquer
# Processing Record 18 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 15 | huarmey
# Processing Record 20 of Set 15 | kungurtug
# Processing Record 21 of Set 15 | mollendo
# Processing Record 22 of Set 15 | lima duarte
# Processing Record 23 of Set 15 | tsaratanana
# Processing Record 24 of Set 15 | matamoros
# Processing Record 25 of Set 15 | umtata
# Processing Record 26 of Set 15 | bubaque
# Processing Record 27 of Set 15 | madang
# Processing Record 28 of Set 15 | zlitan
# Processing Record 29 of Set 15 | graaff-reinet
# Processing Record 30 of Set 15 | tome
# Processing Record 31 of Set 15 | tiarei
# Processing Record 32 of Set 15 | assiniboia
# Processing Record 33 of Set 15 | aksu
# Processing Record 34 of Set 15 | ayagoz
# Processing Record 35 of Set 15 | benguela
# Processing Record 36 of Set 15 | naze
# Processing Record 37 of Set 15 | camacha
# Processing Record 38 of Set 15 | lac-au-saumon
# Processing Record 39 of Set 15 | tarso
# Processing Record 40 of Set 15 | buarcos
# Processing Record 41 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 15 | wenling
# Processing Record 43 of Set 15 | olinda
# Processing Record 44 of Set 15 | pitimbu
# Processing Record 45 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 46 of Set 15 | padang
# Processing Record 47 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 15 | bunia
# Processing Record 49 of Set 15 | leh
# Processing Record 50 of Set 15 | syamzha
# Processing Record 1 of Set 16 | japura
# Processing Record 2 of Set 16 | ulaanbaatar
# Processing Record 3 of Set 16 | shadrinsk
# Processing Record 4 of Set 16 | bay city
# Processing Record 5 of Set 16 | raga
# Processing Record 6 of Set 16 | assomada
# Processing Record 7 of Set 16 | iberia
# Processing Record 8 of Set 16 | borogontsy
# Processing Record 9 of Set 16 | dauphin
# Processing Record 10 of Set 16 | mikhaylovskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Busselton -33.6500  115.3333     56.57        63          89
# 1              Vila  42.0304   -8.1588     90.70        25           0
# 2       Antofagasta -23.6500  -70.4000     68.22        61         100
# 3            Mattru   7.6244  -11.8332     75.24        93          87
# 4         Mahebourg -20.4081   57.7000     70.09        68          40
# ..              ...      ...       ...       ...       ...         ...
# 695        Assomada  15.1000  -23.6833     71.96        76          39
# 696          Iberia  29.9502  -91.7507     94.96        58          20
# 697      Borogontsy  62.6683  131.1683     57.72        74         100
# 698         Dauphin  51.1494 -100.0502     79.36        68          84
# 699  Mikhaylovskoye  51.8239   79.7172     63.79        88          91
#
#      Wind Speed Country                 Date
# 0         23.53      AU  2022-07-09 16:46:14
# 1          3.40      PT  2022-07-09 16:46:14
# 2          6.51      CL  2022-07-09 16:45:45
# 3          5.53      SL  2022-07-09 16:46:15
# 4         16.11      MU  2022-07-09 16:46:15
# ..          ...     ...                  ...
# 695        6.76      CV  2022-07-09 17:04:15
# 696        3.44      US  2022-07-09 17:04:15
# 697        3.94      RU  2022-07-09 17:04:15
# 698        9.01      CA  2022-07-09 17:01:15
# 699       13.82      RU  2022-07-09 17:04:16
#
# [700 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
